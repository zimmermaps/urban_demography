# %% [markdown]
# # Urban Demography - Initial Zonal Data Extraction
#
# - Author: Andrew Zimmer
# - Date Created: 2024-11-14
# - Last Edited:  2024-11-14
# - Version: 1.0
#
# Description:
# - This script processes raster files representing population data for different age and sex groups, calculates zonal statistics (sum) using a shapefile for urban boundaries, and saves the results as CSV files.
# - The processing is parallelized for faster computation, and the results are saved yearly in separate CSV files. The correct shapefile for each year is dynamically selected based on a predefined mapping.
#
# Input Files:
# - Raster files in the directory: './data/raw/worldpop_agesex/' representing population data in GeoTIFF format. These are available for download on the [WorldPop](https://www.worldpop.org/) site
# - Shapefiles in the directory: './Data/Urban-Boundaries/Shapefiles/' corresponding to urban boundaries for specific years. These are available for download on the [GHS-UCDB](https://human-settlement.emergency.copernicus.eu/ghs_ucdb_2024.php) site.
#
# Output Files:
# - Separate CSV files for each year saved in the directory: './01_data/urban_agesex_output/'
# - CSV Filename format: 'population_zonal_stats_{year}.csv'
#
# Steps in Script
# - Reads in raster files for different years and processes them in parallel to calculate zonal statistics.
# - Extracts zonal statistics (sum) for each urban center and age-sex group.
# - Saves the results in separate CSV files for each year.

# %%
import os
import geopandas as gpd
import rasterio
import rasterstats
import pandas as pd
from multiprocessing import Pool

def process_file(file_info):
    """Processes a single file and returns zonal statistics results."""
    filename, input_folder, shapefile_dir, year_shapefile_map = file_info
    file_path = os.path.join(input_folder, filename)
    
    # Extract year, gender, and age from filename
    parts = filename.split('_')
    gender = parts[1]  # 'f' or 'm'
    age = parts[2]
    year = int(parts[3])  # Extract year as integer

    # Determine the correct shapefile based on the year
    shapefile_name = None
    for year_range, shapefile in year_shapefile_map.items():
        if year in year_range:
            shapefile_name = shapefile
            break

    if not shapefile_name:
        print(f"No matching shapefile found for year {year}")
        return []

    print(f"Processing file: {filename} for year {year}, age {age}, sex {gender} using shapefile: {shapefile_name}")

    # Load the appropriate polygons
    polygons = gpd.read_file(os.path.join(shapefile_dir, shapefile_name))

    # Ensure CRS matches between polygons and raster (reproject if necessary)
    with rasterio.open(file_path) as src:
        raster_crs = src.crs  # Expected CRS is WGS 84
        if polygons.crs != raster_crs:
            print(f"Reprojecting polygons from {polygons.crs} to {raster_crs}")
            polygons = polygons.to_crs(raster_crs)

    # Calculate zonal statistics, focusing only on sum
    results = []
    with rasterio.open(file_path) as src:
        stats = rasterstats.zonal_stats(
            polygons,
            src.read(1, masked=True),  # Read only masked areas to save memory
            affine=src.transform,
            stats=['sum'],
            nodata=src.nodata
        )

        # Collect results with appropriate metadata
        for i, stat in enumerate(stats):
            results.append({
                'ID_UC_G0': polygons.iloc[i]['ID_UC_G0'],  # Use the correct ID field
                'year': year,
                'age': age,
                'sex': 'female' if gender == 'f' else 'male',
                'sum': stat['sum']
            })
    return results

def extract_info_to_csv(input_folder, output_folder, shapefile_dir, year_shapefile_map, num_workers=20):
    """
    Extracts zonal statistics from raster files in parallel and saves results to separate yearly CSV files.
    
    Parameters:
        input_folder (str): Path to the folder containing the raster files.
        output_folder (str): Folder path to save the resulting CSV files for each year.
        shapefile_dir (str): Directory containing the reprojected shapefiles.
        year_shapefile_map (dict): Dictionary mapping year ranges to shapefile names.
        num_workers (int): Number of CPU cores to use for parallel processing.
    """
    
    # List and sort files by year
    files = sorted([f for f in os.listdir(input_folder) if f.endswith('.tif')], key=lambda x: int(x.split('_')[3]))

    # Group files by year for sequential processing of each year
    years = sorted(set(int(f.split('_')[3]) for f in files))
    for year in years:
        # Filter files for the current year
        year_files = [f for f in files if int(f.split('_')[3]) == year]
        args = [(f, input_folder, shapefile_dir, year_shapefile_map) for f in year_files]

        # Collect results for the current year
        year_results = []
        with Pool(processes=num_workers) as pool:
            for file_results in pool.imap_unordered(process_file, args):
                if file_results:
                    year_results.extend(file_results)
        
        # Save the current year's results to a CSV file
        os.makedirs(output_folder, exist_ok=True)
        year_df = pd.DataFrame(year_results)
        output_csv = os.path.join(output_folder, f"population_zonal_stats_{year}.csv")
        year_df.to_csv(output_csv, index=False)
        print(f"Zonal statistics for {year} saved to {output_csv}")

# Set input parameters here
input_folder = './01_data/00_worldpop_agesex/'          # Folder containing the .tif files
output_folder = './01_data/01_urban_agesex_output/'     # Folder to save the resulting CSV files
shapefile_dir = './01_data/03_ghs_ucdb/'                # Directory with reprojected shapefiles

# Dictionary mapping year ranges to corresponding shapefile names
# this is changed out if you are only interested in a static boundary. For this - you can use the GHS_UCDB_MTUC_2020_WGS84.shp
# it represents the maximum extent of all urban areas across all years.
year_shapefile_map = {
    range(2000, 2003): 'GHS-UCDB-MTUC-2000-WGS84.shp',
    range(2003, 2008): 'GHS-UCDB-MTUC-2005-WGS84.shp',
    range(2008, 2013): 'GHS-UCDB-MTUC-2010-WGS84.shp',
    range(2013, 2018): 'GHS-UCDB-MTUC-2015-WGS84.shp',
    range(2018, 2021): 'GHS-UCDB-MTUC-2020-WGS84.shp'
}

# Run the function
extract_info_to_csv(input_folder, output_folder, shapefile_dir, year_shapefile_map, num_workers=20)
# Out:
# Processing file: global_f_10_2000_1km.tif for year 2000, age 10, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_m_20_2000_1km.tif for year 2000, age 20, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_f_40_2000_1km.tif for year 2000, age 40, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_m_70_2000_1km.tif for year 2000, age 70, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_m_80_2000_1km.tif for year 2000, age 80, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_m_75_2000_1km.tif for year 2000, age 75, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_f_65_2000_1km.tif for year 2000, age 65, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_f_35_2000_1km.tif for year 2000, age 35, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_m_05_2000_1km.tif for year 2000, age 05, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_m_55_2000_1km.tif for year 2000, age 55, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_m_00_2000_1km.tif for year 2000, age 00, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_f_15_2000_1km.tif for year 2000, age 15, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_m_50_2000_1km.tif for year 2000, age 50, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_f_60_2000_1km.tif for year 2000, age 60, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_f_30_2000_1km.tif for year 2000, age 30, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_m_01_2000_1km.tif for year 2000, age 01, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
#
#
# Processing file: global_m_40_2000_1km.tif for year 2000, age 40, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_f_70_2000_1km.tif for year 2000, age 70, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing file: global_m_25_2000_1km.tif for year 2000, age 25, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_f_45_2000_1km.tif for year 2000, age 45, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
#
# Processing file: global_m_10_2000_1km.tif for year 2000, age 10, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_f_20_2000_1km.tif for year 2000, age 20, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_f_25_2000_1km.tif for year 2000, age 25, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_m_15_2000_1km.tif for year 2000, age 15, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_f_80_2000_1km.tif for year 2000, age 80, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_f_75_2000_1km.tif for year 2000, age 75, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_m_45_2000_1km.tif for year 2000, age 45, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_f_55_2000_1km.tif for year 2000, age 55, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_m_65_2000_1km.tif for year 2000, age 65, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_f_05_2000_1km.tif for year 2000, age 05, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_m_35_2000_1km.tif for year 2000, age 35, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_m_30_2000_1km.tif for year 2000, age 30, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_f_01_2000_1km.tif for year 2000, age 01, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_f_00_2000_1km.tif for year 2000, age 00, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_m_60_2000_1km.tif for year 2000, age 60, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_f_50_2000_1km.tif for year 2000, age 50, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Zonal statistics for 2000 saved to /home/p18q126/myFolder/Projects/Urban-Demography/Data/Urban-AgeSex-Output/population_zonal_stats_2000.csv
# Processing file: global_m_00_2001_1km.tif for year 2001, age 00, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_f_35_2001_1km.tif for year 2001, age 35, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_f_45_2001_1km.tif for year 2001, age 45, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_f_30_2001_1km.tif for year 2001, age 30, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_f_01_2001_1km.tif for year 2001, age 01, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_f_15_2001_1km.tif for year 2001, age 15, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_m_75_2001_1km.tif for year 2001, age 75, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_m_70_2001_1km.tif for year 2001, age 70, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_f_65_2001_1km.tif for year 2001, age 65, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_m_05_2001_1km.tif for year 2001, age 05, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_f_60_2001_1km.tif for year 2001, age 60, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_m_20_2001_1km.tif for year 2001, age 20, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_m_55_2001_1km.tif for year 2001, age 55, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_m_30_2001_1km.tif for year 2001, age 30, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_f_10_2001_1km.tif for year 2001, age 10, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_m_01_2001_1km.tif for year 2001, age 01, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_m_50_2001_1km.tif for year 2001, age 50, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_m_25_2001_1km.tif for year 2001, age 25, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_m_80_2001_1km.tif for year 2001, age 80, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_f_40_2001_1km.tif for year 2001, age 40, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing file: global_f_00_2001_1km.tif for year 2001, age 00, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_m_60_2001_1km.tif for year 2001, age 60, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_f_50_2001_1km.tif for year 2001, age 50, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_f_55_2001_1km.tif for year 2001, age 55, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_m_65_2001_1km.tif for year 2001, age 65, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_f_05_2001_1km.tif for year 2001, age 05, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_m_35_2001_1km.tif for year 2001, age 35, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_f_25_2001_1km.tif for year 2001, age 25, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_m_15_2001_1km.tif for year 2001, age 15, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_f_75_2001_1km.tif for year 2001, age 75, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_f_80_2001_1km.tif for year 2001, age 80, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_m_45_2001_1km.tif for year 2001, age 45, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_m_40_2001_1km.tif for year 2001, age 40, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_f_70_2001_1km.tif for year 2001, age 70, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_m_10_2001_1km.tif for year 2001, age 10, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_f_20_2001_1km.tif for year 2001, age 20, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# /home/p18q126/.local/lib/python3.9/site-packages/pandas/core/indexes/base.py:7834: RuntimeWarning: invalid value encountered in cast
#   values = values.astype(str)
# Zonal statistics for 2001 saved to /home/p18q126/myFolder/Projects/Urban-Demography/Data/Urban-AgeSex-Output/population_zonal_stats_2001.csv
# Processing file: global_m_40_2002_1km.tif for year 2002, age 40, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_f_01_2002_1km.tif for year 2002, age 01, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_m_15_2002_1km.tif for year 2002, age 15, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_f_80_2002_1km.tif for year 2002, age 80, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_f_55_2002_1km.tif for year 2002, age 55, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_f_20_2002_1km.tif for year 2002, age 20, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_m_35_2002_1km.tif for year 2002, age 35, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_m_45_2002_1km.tif for year 2002, age 45, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_f_25_2002_1km.tif for year 2002, age 25, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_f_65_2002_1km.tif for year 2002, age 65, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_f_00_2002_1km.tif for year 2002, age 00, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_f_05_2002_1km.tif for year 2002, age 05, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_m_60_2002_1km.tif for year 2002, age 60, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_m_65_2002_1km.tif for year 2002, age 65, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_m_30_2002_1km.tif for year 2002, age 30, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_m_10_2002_1km.tif for year 2002, age 10, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_m_55_2002_1km.tif for year 2002, age 55, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_f_75_2002_1km.tif for year 2002, age 75, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shpProcessing file: global_f_70_2002_1km.tif for year 2002, age 70, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing file: global_f_50_2002_1km.tif for year 2002, age 50, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_m_05_2002_1km.tif for year 2002, age 05, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_f_35_2002_1km.tif for year 2002, age 35, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_f_30_2002_1km.tif for year 2002, age 30, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_m_01_2002_1km.tif for year 2002, age 01, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_m_00_2002_1km.tif for year 2002, age 00, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_f_60_2002_1km.tif for year 2002, age 60, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_m_50_2002_1km.tif for year 2002, age 50, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_f_40_2002_1km.tif for year 2002, age 40, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_m_70_2002_1km.tif for year 2002, age 70, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_f_10_2002_1km.tif for year 2002, age 10, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_m_20_2002_1km.tif for year 2002, age 20, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_m_25_2002_1km.tif for year 2002, age 25, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_f_15_2002_1km.tif for year 2002, age 15, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_m_80_2002_1km.tif for year 2002, age 80, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_m_75_2002_1km.tif for year 2002, age 75, sex m using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Processing file: global_f_45_2002_1km.tif for year 2002, age 45, sex f using shapefile: GHS-UCDB-MTUC-2000-WGS84.shp
# Zonal statistics for 2002 saved to /home/p18q126/myFolder/Projects/Urban-Demography/Data/Urban-AgeSex-Output/population_zonal_stats_2002.csv
# Processing file: global_f_05_2003_1km.tif for year 2003, age 05, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_10_2003_1km.tif for year 2003, age 10, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_75_2003_1km.tif for year 2003, age 75, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_65_2003_1km.tif for year 2003, age 65, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_80_2003_1km.tif for year 2003, age 80, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_15_2003_1km.tif for year 2003, age 15, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_50_2003_1km.tif for year 2003, age 50, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_25_2003_1km.tif for year 2003, age 25, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_35_2003_1km.tif for year 2003, age 35, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_30_2003_1km.tif for year 2003, age 30, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_25_2003_1km.tif for year 2003, age 25, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_45_2003_1km.tif for year 2003, age 45, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_40_2003_1km.tif for year 2003, age 40, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_01_2003_1km.tif for year 2003, age 01, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_55_2003_1km.tif for year 2003, age 55, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
#
# Processing file: global_f_00_2003_1km.tif for year 2003, age 00, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
#
# Processing file: global_m_60_2003_1km.tif for year 2003, age 60, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_20_2003_1km.tif for year 2003, age 20, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_15_2003_1km.tif for year 2003, age 15, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_70_2003_1km.tif for year 2003, age 70, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing file: global_m_75_2003_1km.tif for year 2003, age 75, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_m_80_2003_1km.tif for year 2003, age 80, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_f_45_2003_1km.tif for year 2003, age 45, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_f_40_2003_1km.tif for year 2003, age 40, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_m_70_2003_1km.tif for year 2003, age 70, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_f_10_2003_1km.tif for year 2003, age 10, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_m_20_2003_1km.tif for year 2003, age 20, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_m_01_2003_1km.tif for year 2003, age 01, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_f_30_2003_1km.tif for year 2003, age 30, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_m_00_2003_1km.tif for year 2003, age 00, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_f_60_2003_1km.tif for year 2003, age 60, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_m_50_2003_1km.tif for year 2003, age 50, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_m_55_2003_1km.tif for year 2003, age 55, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_f_65_2003_1km.tif for year 2003, age 65, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_m_05_2003_1km.tif for year 2003, age 05, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_f_35_2003_1km.tif for year 2003, age 35, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Zonal statistics for 2003 saved to /home/p18q126/myFolder/Projects/Urban-Demography/Data/Urban-AgeSex-Output/population_zonal_stats_2003.csv
# Processing file: global_f_30_2004_1km.tif for year 2004, age 30, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_70_2004_1km.tif for year 2004, age 70, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_35_2004_1km.tif for year 2004, age 35, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_65_2004_1km.tif for year 2004, age 65, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_75_2004_1km.tif for year 2004, age 75, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_01_2004_1km.tif for year 2004, age 01, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_60_2004_1km.tif for year 2004, age 60, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_55_2004_1km.tif for year 2004, age 55, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_00_2004_1km.tif for year 2004, age 00, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_50_2004_1km.tif for year 2004, age 50, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_80_2004_1km.tif for year 2004, age 80, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_25_2004_1km.tif for year 2004, age 25, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_05_2004_1km.tif for year 2004, age 05, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_70_2004_1km.tif for year 2004, age 70, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_45_2004_1km.tif for year 2004, age 45, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_10_2004_1km.tif for year 2004, age 10, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_15_2004_1km.tif for year 2004, age 15, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_20_2004_1km.tif for year 2004, age 20, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_40_2004_1km.tif for year 2004, age 40, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_40_2004_1km.tif for year 2004, age 40, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing file: global_m_10_2004_1km.tif for year 2004, age 10, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_f_20_2004_1km.tif for year 2004, age 20, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_f_25_2004_1km.tif for year 2004, age 25, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_m_15_2004_1km.tif for year 2004, age 15, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_f_80_2004_1km.tif for year 2004, age 80, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_f_75_2004_1km.tif for year 2004, age 75, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_m_45_2004_1km.tif for year 2004, age 45, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_f_55_2004_1km.tif for year 2004, age 55, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_m_65_2004_1km.tif for year 2004, age 65, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_f_05_2004_1km.tif for year 2004, age 05, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_m_35_2004_1km.tif for year 2004, age 35, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_m_30_2004_1km.tif for year 2004, age 30, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_f_01_2004_1km.tif for year 2004, age 01, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_f_00_2004_1km.tif for year 2004, age 00, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_m_60_2004_1km.tif for year 2004, age 60, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_f_50_2004_1km.tif for year 2004, age 50, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Zonal statistics for 2004 saved to /home/p18q126/myFolder/Projects/Urban-Demography/Data/Urban-AgeSex-Output/population_zonal_stats_2004.csv
# Processing file: global_m_00_2005_1km.tif for year 2005, age 00, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_35_2005_1km.tif for year 2005, age 35, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_30_2005_1km.tif for year 2005, age 30, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_40_2005_1km.tif for year 2005, age 40, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_05_2005_1km.tif for year 2005, age 05, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_10_2005_1km.tif for year 2005, age 10, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_45_2005_1km.tif for year 2005, age 45, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_30_2005_1km.tif for year 2005, age 30, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_70_2005_1km.tif for year 2005, age 70, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_60_2005_1km.tif for year 2005, age 60, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_25_2005_1km.tif for year 2005, age 25, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_55_2005_1km.tif for year 2005, age 55, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_01_2005_1km.tif for year 2005, age 01, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_20_2005_1km.tif for year 2005, age 20, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_75_2005_1km.tif for year 2005, age 75, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_50_2005_1km.tif for year 2005, age 50, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_65_2005_1km.tif for year 2005, age 65, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_15_2005_1km.tif for year 2005, age 15, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_80_2005_1km.tif for year 2005, age 80, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
#
# Processing file: global_f_01_2005_1km.tif for year 2005, age 01, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing file: global_f_00_2005_1km.tif for year 2005, age 00, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_m_60_2005_1km.tif for year 2005, age 60, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_f_50_2005_1km.tif for year 2005, age 50, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_f_55_2005_1km.tif for year 2005, age 55, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_m_65_2005_1km.tif for year 2005, age 65, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_f_05_2005_1km.tif for year 2005, age 05, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_m_35_2005_1km.tif for year 2005, age 35, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_f_25_2005_1km.tif for year 2005, age 25, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_m_15_2005_1km.tif for year 2005, age 15, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_f_75_2005_1km.tif for year 2005, age 75, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_f_80_2005_1km.tif for year 2005, age 80, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_m_45_2005_1km.tif for year 2005, age 45, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_m_40_2005_1km.tif for year 2005, age 40, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_f_70_2005_1km.tif for year 2005, age 70, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_m_10_2005_1km.tif for year 2005, age 10, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_f_20_2005_1km.tif for year 2005, age 20, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Zonal statistics for 2005 saved to /home/p18q126/myFolder/Projects/Urban-Demography/Data/Urban-AgeSex-Output/population_zonal_stats_2005.csv
# Processing file: global_m_35_2006_1km.tif for year 2006, age 35, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_55_2006_1km.tif for year 2006, age 55, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_65_2006_1km.tif for year 2006, age 65, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_00_2006_1km.tif for year 2006, age 00, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_60_2006_1km.tif for year 2006, age 60, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_50_2006_1km.tif for year 2006, age 50, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_30_2006_1km.tif for year 2006, age 30, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_05_2006_1km.tif for year 2006, age 05, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_10_2006_1km.tif for year 2006, age 10, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_01_2006_1km.tif for year 2006, age 01, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_25_2006_1km.tif for year 2006, age 25, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_40_2006_1km.tif for year 2006, age 40, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_45_2006_1km.tif for year 2006, age 45, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_75_2006_1km.tif for year 2006, age 75, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_65_2006_1km.tif for year 2006, age 65, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_80_2006_1km.tif for year 2006, age 80, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_70_2006_1km.tif for year 2006, age 70, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_20_2006_1km.tif for year 2006, age 20, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_15_2006_1km.tif for year 2006, age 15, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
#
#
#
#
# Processing file: global_m_55_2006_1km.tif for year 2006, age 55, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing file: global_m_05_2006_1km.tif for year 2006, age 05, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_f_35_2006_1km.tif for year 2006, age 35, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_f_30_2006_1km.tif for year 2006, age 30, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_m_01_2006_1km.tif for year 2006, age 01, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_m_00_2006_1km.tif for year 2006, age 00, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_f_60_2006_1km.tif for year 2006, age 60, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_m_50_2006_1km.tif for year 2006, age 50, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_f_40_2006_1km.tif for year 2006, age 40, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_m_70_2006_1km.tif for year 2006, age 70, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_f_10_2006_1km.tif for year 2006, age 10, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_m_20_2006_1km.tif for year 2006, age 20, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_m_25_2006_1km.tif for year 2006, age 25, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_f_15_2006_1km.tif for year 2006, age 15, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_m_80_2006_1km.tif for year 2006, age 80, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_m_75_2006_1km.tif for year 2006, age 75, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_f_45_2006_1km.tif for year 2006, age 45, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Zonal statistics for 2006 saved to /home/p18q126/myFolder/Projects/Urban-Demography/Data/Urban-AgeSex-Output/population_zonal_stats_2006.csv
# Processing file: global_m_15_2007_1km.tif for year 2007, age 15, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_70_2007_1km.tif for year 2007, age 70, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_40_2007_1km.tif for year 2007, age 40, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_25_2007_1km.tif for year 2007, age 25, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_80_2007_1km.tif for year 2007, age 80, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_05_2007_1km.tif for year 2007, age 05, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_45_2007_1km.tif for year 2007, age 45, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_15_2007_1km.tif for year 2007, age 15, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_25_2007_1km.tif for year 2007, age 25, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_30_2007_1km.tif for year 2007, age 30, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_65_2007_1km.tif for year 2007, age 65, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_35_2007_1km.tif for year 2007, age 35, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_75_2007_1km.tif for year 2007, age 75, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
#
#
#
#
# Processing file: global_m_60_2007_1km.tif for year 2007, age 60, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_01_2007_1km.tif for year 2007, age 01, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_20_2007_1km.tif for year 2007, age 20, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_f_00_2007_1km.tif for year 2007, age 00, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
#
# Processing file: global_f_50_2007_1km.tif for year 2007, age 50, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shpProcessing file: global_m_10_2007_1km.tif for year 2007, age 10, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_f_55_2007_1km.tif for year 2007, age 55, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
#
#
#
#
#
#
#
#
#
#
#
# Processing file: global_m_75_2007_1km.tif for year 2007, age 75, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_m_80_2007_1km.tif for year 2007, age 80, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_f_45_2007_1km.tif for year 2007, age 45, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_f_40_2007_1km.tif for year 2007, age 40, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_m_70_2007_1km.tif for year 2007, age 70, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_f_10_2007_1km.tif for year 2007, age 10, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_m_20_2007_1km.tif for year 2007, age 20, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_m_01_2007_1km.tif for year 2007, age 01, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_f_30_2007_1km.tif for year 2007, age 30, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_m_00_2007_1km.tif for year 2007, age 00, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_f_60_2007_1km.tif for year 2007, age 60, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_m_50_2007_1km.tif for year 2007, age 50, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_m_55_2007_1km.tif for year 2007, age 55, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_f_65_2007_1km.tif for year 2007, age 65, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_m_05_2007_1km.tif for year 2007, age 05, sex m using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Processing file: global_f_35_2007_1km.tif for year 2007, age 35, sex f using shapefile: GHS-UCDB-MTUC-2005-WGS84.shp
# Zonal statistics for 2007 saved to /home/p18q126/myFolder/Projects/Urban-Demography/Data/Urban-AgeSex-Output/population_zonal_stats_2007.csv
# Processing file: global_f_10_2008_1km.tif for year 2008, age 10, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_f_65_2008_1km.tif for year 2008, age 65, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_m_80_2008_1km.tif for year 2008, age 80, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_m_50_2008_1km.tif for year 2008, age 50, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_f_60_2008_1km.tif for year 2008, age 60, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_f_70_2008_1km.tif for year 2008, age 70, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_m_40_2008_1km.tif for year 2008, age 40, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_f_45_2008_1km.tif for year 2008, age 45, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_m_25_2008_1km.tif for year 2008, age 25, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_m_75_2008_1km.tif for year 2008, age 75, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_m_70_2008_1km.tif for year 2008, age 70, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
#
# Processing file: global_f_30_2008_1km.tif for year 2008, age 30, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_f_15_2008_1km.tif for year 2008, age 15, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_m_20_2008_1km.tif for year 2008, age 20, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_f_40_2008_1km.tif for year 2008, age 40, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_m_00_2008_1km.tif for year 2008, age 00, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_m_55_2008_1km.tif for year 2008, age 55, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_f_35_2008_1km.tif for year 2008, age 35, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_m_01_2008_1km.tif for year 2008, age 01, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_m_05_2008_1km.tif for year 2008, age 05, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing file: global_m_10_2008_1km.tif for year 2008, age 10, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_f_20_2008_1km.tif for year 2008, age 20, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_f_25_2008_1km.tif for year 2008, age 25, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_m_15_2008_1km.tif for year 2008, age 15, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_f_75_2008_1km.tif for year 2008, age 75, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_f_80_2008_1km.tif for year 2008, age 80, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_m_45_2008_1km.tif for year 2008, age 45, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_f_55_2008_1km.tif for year 2008, age 55, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_m_65_2008_1km.tif for year 2008, age 65, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_f_05_2008_1km.tif for year 2008, age 05, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_m_35_2008_1km.tif for year 2008, age 35, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_f_01_2008_1km.tif for year 2008, age 01, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_m_30_2008_1km.tif for year 2008, age 30, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_f_00_2008_1km.tif for year 2008, age 00, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_m_60_2008_1km.tif for year 2008, age 60, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_f_50_2008_1km.tif for year 2008, age 50, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Zonal statistics for 2008 saved to /home/p18q126/myFolder/Projects/Urban-Demography/Data/Urban-AgeSex-Output/population_zonal_stats_2008.csv
# Processing file: global_f_30_2009_1km.tif for year 2009, age 30, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_m_00_2009_1km.tif for year 2009, age 00, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_m_01_2009_1km.tif for year 2009, age 01, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_m_55_2009_1km.tif for year 2009, age 55, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_m_50_2009_1km.tif for year 2009, age 50, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_f_65_2009_1km.tif for year 2009, age 65, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_f_60_2009_1km.tif for year 2009, age 60, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_m_70_2009_1km.tif for year 2009, age 70, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_f_45_2009_1km.tif for year 2009, age 45, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_m_20_2009_1km.tif for year 2009, age 20, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_m_80_2009_1km.tif for year 2009, age 80, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_f_15_2009_1km.tif for year 2009, age 15, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_f_01_2009_1km.tif for year 2009, age 01, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_m_75_2009_1km.tif for year 2009, age 75, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_f_40_2009_1km.tif for year 2009, age 40, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_f_10_2009_1km.tif for year 2009, age 10, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
#
#
# Processing file: global_m_05_2009_1km.tif for year 2009, age 05, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_m_30_2009_1km.tif for year 2009, age 30, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_f_35_2009_1km.tif for year 2009, age 35, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
#
#
#
#
#
#
#
#
#
# Processing file: global_m_25_2009_1km.tif for year 2009, age 25, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
#
#
#
#
#
# Processing file: global_f_00_2009_1km.tif for year 2009, age 00, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_m_60_2009_1km.tif for year 2009, age 60, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_f_50_2009_1km.tif for year 2009, age 50, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_f_55_2009_1km.tif for year 2009, age 55, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_m_65_2009_1km.tif for year 2009, age 65, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_f_05_2009_1km.tif for year 2009, age 05, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_m_35_2009_1km.tif for year 2009, age 35, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_f_25_2009_1km.tif for year 2009, age 25, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_m_15_2009_1km.tif for year 2009, age 15, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_f_80_2009_1km.tif for year 2009, age 80, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_f_75_2009_1km.tif for year 2009, age 75, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_m_45_2009_1km.tif for year 2009, age 45, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_m_40_2009_1km.tif for year 2009, age 40, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_f_70_2009_1km.tif for year 2009, age 70, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_m_10_2009_1km.tif for year 2009, age 10, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_f_20_2009_1km.tif for year 2009, age 20, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Zonal statistics for 2009 saved to /home/p18q126/myFolder/Projects/Urban-Demography/Data/Urban-AgeSex-Output/population_zonal_stats_2009.csv
# Processing file: global_m_05_2010_1km.tif for year 2010, age 05, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_f_35_2010_1km.tif for year 2010, age 35, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_m_25_2010_1km.tif for year 2010, age 25, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_m_55_2010_1km.tif for year 2010, age 55, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_f_45_2010_1km.tif for year 2010, age 45, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_f_15_2010_1km.tif for year 2010, age 15, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_m_50_2010_1km.tif for year 2010, age 50, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_m_00_2010_1km.tif for year 2010, age 00, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_m_35_2010_1km.tif for year 2010, age 35, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_f_10_2010_1km.tif for year 2010, age 10, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_m_01_2010_1km.tif for year 2010, age 01, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_f_60_2010_1km.tif for year 2010, age 60, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_f_40_2010_1km.tif for year 2010, age 40, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_m_70_2010_1km.tif for year 2010, age 70, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_m_20_2010_1km.tif for year 2010, age 20, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_f_65_2010_1km.tif for year 2010, age 65, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_m_75_2010_1km.tif for year 2010, age 75, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_m_80_2010_1km.tif for year 2010, age 80, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_f_30_2010_1km.tif for year 2010, age 30, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shpProcessing file: global_f_05_2010_1km.tif for year 2010, age 05, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing file: global_f_55_2010_1km.tif for year 2010, age 55, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_m_65_2010_1km.tif for year 2010, age 65, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_m_60_2010_1km.tif for year 2010, age 60, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_f_50_2010_1km.tif for year 2010, age 50, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_m_30_2010_1km.tif for year 2010, age 30, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_f_01_2010_1km.tif for year 2010, age 01, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_f_00_2010_1km.tif for year 2010, age 00, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_m_10_2010_1km.tif for year 2010, age 10, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_f_20_2010_1km.tif for year 2010, age 20, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_m_40_2010_1km.tif for year 2010, age 40, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_f_70_2010_1km.tif for year 2010, age 70, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_f_80_2010_1km.tif for year 2010, age 80, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_f_75_2010_1km.tif for year 2010, age 75, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_m_45_2010_1km.tif for year 2010, age 45, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_f_25_2010_1km.tif for year 2010, age 25, sex f using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# Processing file: global_m_15_2010_1km.tif for year 2010, age 15, sex m using shapefile: GHS-UCDB-MTUC-2010-WGS84.shp
# ...
# Processing file: global_f_05_2017_1km.tif for year 2017, age 05, sex f using shapefile: GHS-UCDB-MTUC-2015-WGS84.shp
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing file: global_m_01_2017_1km.tif for year 2017, age 01, sex m using shapefile: GHS-UCDB-MTUC-2015-WGS84.shp
# Processing file: global_f_30_2017_1km.tif for year 2017, age 30, sex f using shapefile: GHS-UCDB-MTUC-2015-WGS84.shp
# Processing file: global_m_00_2017_1km.tif for year 2017, age 00, sex m using shapefile: GHS-UCDB-MTUC-2015-WGS84.shp
# Processing file: global_m_05_2017_1km.tif for year 2017, age 05, sex m using shapefile: GHS-UCDB-MTUC-2015-WGS84.shp
# Processing file: global_f_35_2017_1km.tif for year 2017, age 35, sex f using shapefile: GHS-UCDB-MTUC-2015-WGS84.shp
# Processing file: global_m_55_2017_1km.tif for year 2017, age 55, sex m using shapefile: GHS-UCDB-MTUC-2015-WGS84.shp
# Processing file: global_f_65_2017_1km.tif for year 2017, age 65, sex f using shapefile: GHS-UCDB-MTUC-2015-WGS84.shp
# Processing file: global_m_75_2017_1km.tif for year 2017, age 75, sex m using shapefile: GHS-UCDB-MTUC-2015-WGS84.shp
# Processing file: global_m_80_2017_1km.tif for year 2017, age 80, sex m using shapefile: GHS-UCDB-MTUC-2015-WGS84.shp
# Processing file: global_f_45_2017_1km.tif for year 2017, age 45, sex f using shapefile: GHS-UCDB-MTUC-2015-WGS84.shp
# Processing file: global_m_25_2017_1km.tif for year 2017, age 25, sex m using shapefile: GHS-UCDB-MTUC-2015-WGS84.shp
# Processing file: global_f_15_2017_1km.tif for year 2017, age 15, sex f using shapefile: GHS-UCDB-MTUC-2015-WGS84.shp
# Processing file: global_f_10_2017_1km.tif for year 2017, age 10, sex f using shapefile: GHS-UCDB-MTUC-2015-WGS84.shp
# Processing file: global_m_20_2017_1km.tif for year 2017, age 20, sex m using shapefile: GHS-UCDB-MTUC-2015-WGS84.shp
# Processing file: global_f_40_2017_1km.tif for year 2017, age 40, sex f using shapefile: GHS-UCDB-MTUC-2015-WGS84.shp
# Processing file: global_m_70_2017_1km.tif for year 2017, age 70, sex m using shapefile: GHS-UCDB-MTUC-2015-WGS84.shp
# Zonal statistics for 2017 saved to /home/p18q126/myFolder/Projects/Urban-Demography/Data/Urban-AgeSex-Output/population_zonal_stats_2017.csv
# Processing file: global_m_01_2018_1km.tif for year 2018, age 01, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_m_75_2018_1km.tif for year 2018, age 75, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_m_55_2018_1km.tif for year 2018, age 55, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_m_05_2018_1km.tif for year 2018, age 05, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_m_70_2018_1km.tif for year 2018, age 70, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_f_05_2018_1km.tif for year 2018, age 05, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_m_50_2018_1km.tif for year 2018, age 50, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_m_25_2018_1km.tif for year 2018, age 25, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_m_35_2018_1km.tif for year 2018, age 35, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_f_45_2018_1km.tif for year 2018, age 45, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_f_30_2018_1km.tif for year 2018, age 30, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_f_60_2018_1km.tif for year 2018, age 60, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_f_35_2018_1km.tif for year 2018, age 35, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_m_80_2018_1km.tif for year 2018, age 80, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_f_10_2018_1km.tif for year 2018, age 10, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_m_20_2018_1km.tif for year 2018, age 20, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_m_00_2018_1km.tif for year 2018, age 00, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_f_15_2018_1km.tif for year 2018, age 15, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
#
#
#
#
# Processing file: global_f_65_2018_1km.tif for year 2018, age 65, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_f_40_2018_1km.tif for year 2018, age 40, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing file: global_f_55_2018_1km.tif for year 2018, age 55, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_m_65_2018_1km.tif for year 2018, age 65, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_m_60_2018_1km.tif for year 2018, age 60, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_f_50_2018_1km.tif for year 2018, age 50, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_f_01_2018_1km.tif for year 2018, age 01, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_m_30_2018_1km.tif for year 2018, age 30, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_f_00_2018_1km.tif for year 2018, age 00, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_m_10_2018_1km.tif for year 2018, age 10, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_f_20_2018_1km.tif for year 2018, age 20, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_m_40_2018_1km.tif for year 2018, age 40, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_f_70_2018_1km.tif for year 2018, age 70, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_f_75_2018_1km.tif for year 2018, age 75, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_f_80_2018_1km.tif for year 2018, age 80, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_m_45_2018_1km.tif for year 2018, age 45, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_f_25_2018_1km.tif for year 2018, age 25, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_m_15_2018_1km.tif for year 2018, age 15, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Zonal statistics for 2018 saved to /home/p18q126/myFolder/Projects/Urban-Demography/Data/Urban-AgeSex-Output/population_zonal_stats_2018.csv
# Processing file: global_m_25_2019_1km.tif for year 2019, age 25, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_f_35_2019_1km.tif for year 2019, age 35, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_m_80_2019_1km.tif for year 2019, age 80, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_m_75_2019_1km.tif for year 2019, age 75, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_f_45_2019_1km.tif for year 2019, age 45, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_f_30_2019_1km.tif for year 2019, age 30, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_m_01_2019_1km.tif for year 2019, age 01, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_m_55_2019_1km.tif for year 2019, age 55, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_f_80_2019_1km.tif for year 2019, age 80, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_f_75_2019_1km.tif for year 2019, age 75, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_f_65_2019_1km.tif for year 2019, age 65, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_m_50_2019_1km.tif for year 2019, age 50, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_f_15_2019_1km.tif for year 2019, age 15, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_m_05_2019_1km.tif for year 2019, age 05, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_f_10_2019_1km.tif for year 2019, age 10, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_f_60_2019_1km.tif for year 2019, age 60, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_m_70_2019_1km.tif for year 2019, age 70, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_m_20_2019_1km.tif for year 2019, age 20, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_f_40_2019_1km.tif for year 2019, age 40, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_m_00_2019_1km.tif for year 2019, age 00, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing file: global_m_45_2019_1km.tif for year 2019, age 45, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_f_25_2019_1km.tif for year 2019, age 25, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_m_15_2019_1km.tif for year 2019, age 15, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_m_10_2019_1km.tif for year 2019, age 10, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_f_20_2019_1km.tif for year 2019, age 20, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_m_40_2019_1km.tif for year 2019, age 40, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_f_70_2019_1km.tif for year 2019, age 70, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_m_60_2019_1km.tif for year 2019, age 60, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_f_50_2019_1km.tif for year 2019, age 50, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_m_30_2019_1km.tif for year 2019, age 30, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_f_01_2019_1km.tif for year 2019, age 01, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_f_00_2019_1km.tif for year 2019, age 00, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_f_05_2019_1km.tif for year 2019, age 05, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_m_35_2019_1km.tif for year 2019, age 35, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_f_55_2019_1km.tif for year 2019, age 55, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_m_65_2019_1km.tif for year 2019, age 65, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Zonal statistics for 2019 saved to /home/p18q126/myFolder/Projects/Urban-Demography/Data/Urban-AgeSex-Output/population_zonal_stats_2019.csv
# Processing file: global_f_25_2020_1km.tif for year 2020, age 25, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_f_80_2020_1km.tif for year 2020, age 80, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_m_15_2020_1km.tif for year 2020, age 15, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_m_40_2020_1km.tif for year 2020, age 40, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_m_10_2020_1km.tif for year 2020, age 10, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_m_45_2020_1km.tif for year 2020, age 45, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_f_75_2020_1km.tif for year 2020, age 75, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_f_01_2020_1km.tif for year 2020, age 01, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_m_60_2020_1km.tif for year 2020, age 60, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_f_00_2020_1km.tif for year 2020, age 00, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_m_35_2020_1km.tif for year 2020, age 35, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_f_50_2020_1km.tif for year 2020, age 50, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_f_15_2020_1km.tif for year 2020, age 15, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shpProcessing file: global_m_65_2020_1km.tif for year 2020, age 65, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_f_05_2020_1km.tif for year 2020, age 05, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
#
# Processing file: global_m_25_2020_1km.tif for year 2020, age 25, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
#
# Processing file: global_f_20_2020_1km.tif for year 2020, age 20, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
#
# Processing file: global_f_55_2020_1km.tif for year 2020, age 55, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
#
# Processing file: global_f_70_2020_1km.tif for year 2020, age 70, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
#
#
#
# Processing file: global_m_30_2020_1km.tif for year 2020, age 30, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
#
#
#
#
# Processing file: global_f_45_2020_1km.tif for year 2020, age 45, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_m_75_2020_1km.tif for year 2020, age 75, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_m_80_2020_1km.tif for year 2020, age 80, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_m_70_2020_1km.tif for year 2020, age 70, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_f_40_2020_1km.tif for year 2020, age 40, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_m_20_2020_1km.tif for year 2020, age 20, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_f_10_2020_1km.tif for year 2020, age 10, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_m_00_2020_1km.tif for year 2020, age 00, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_m_01_2020_1km.tif for year 2020, age 01, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_f_30_2020_1km.tif for year 2020, age 30, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_m_50_2020_1km.tif for year 2020, age 50, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_f_60_2020_1km.tif for year 2020, age 60, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_f_65_2020_1km.tif for year 2020, age 65, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_m_55_2020_1km.tif for year 2020, age 55, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_f_35_2020_1km.tif for year 2020, age 35, sex f using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Processing file: global_m_05_2020_1km.tif for year 2020, age 05, sex m using shapefile: GHS-UCDB-MTUC-2020-WGS84.shp
# Zonal statistics for 2020 saved to /home/p18q126/myFolder/Projects/Urban-Demography/Data/Urban-AgeSex-Output/population_zonal_stats_2020.csv
